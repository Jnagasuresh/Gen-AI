# %%
# %pip install pandas numpy gensim nltk

# %%
import pandas as pd
import numpy as np
import os
import gensim
import nltk

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
for file in os.listdir('./data/'):
    print(file)
# Out:
# story1.txt
# story2.txt

# %%
f=open(r"C:\src\pyprojects\Full-Stack-GenAI-Bootcamp-1.0\04-12-2026\data\story1.txt",encoding='unicode_escape')

# %%
corpus = f.read()

# %%
print(corpus)
# Out:
# Once upon a time, there was a young boy named Arjun who lived in a small town surrounded by hills and rivers. He was very curious about how things worked and always asked questions. His parents often smiled at his curiosity and encouraged him to learn more.
#
# Every day after school, Arjun would sit with his books and explore different topics. He was especially fascinated by science and technology. He wanted to understand how machines think and whether they could become as intelligent as humans.
#
# One day, while browsing through an old computer at school, Arjun discovered the concept of artificial intelligence. He read about how machines can learn from data, recognize patterns, and even make decisions. This idea completely amazed him.
#
# He started imagining a future where machines could help humans solve complex problems. That day, he made a decision that he wanted to become an AI engineer.
#
# ...

# %%
sent_tokenize(corpus)
# Out:
# ['Once upon a time, there was a young boy named Arjun who lived in a small town surrounded by hills and rivers.',
#  'He was very curious about how things worked and always asked questions.',
#  'His parents often smiled at his curiosity and encouraged him to learn more.',
#  'Every day after school, Arjun would sit with his books and explore different topics.',
#  'He was especially fascinated by science and technology.',
#  'He wanted to understand how machines think and whether they could become as intelligent as humans.',
#  'One day, while browsing through an old computer at school, Arjun discovered the concept of artificial intelligence.',
#  'He read about how machines can learn from data, recognize patterns, and even make decisions.',
#  'This idea completely amazed him.',
#  'He started imagining a future where machines could help humans solve complex problems.',
#  'That day, he made a decision that he wanted to become an AI engineer.',
# ...

# %%
raw_sent = sent_tokenize(corpus)

# %%
for i in raw_sent:
    print(simple_preprocess(i))
# Out:
# ['once', 'upon', 'time', 'there', 'was', 'young', 'boy', 'named', 'arjun', 'who', 'lived', 'in', 'small', 'town', 'surrounded', 'by', 'hills', 'and', 'rivers']
# ['he', 'was', 'very', 'curious', 'about', 'how', 'things', 'worked', 'and', 'always', 'asked', 'questions']
# ['his', 'parents', 'often', 'smiled', 'at', 'his', 'curiosity', 'and', 'encouraged', 'him', 'to', 'learn', 'more']
# ['every', 'day', 'after', 'school', 'arjun', 'would', 'sit', 'with', 'his', 'books', 'and', 'explore', 'different', 'topics']
# ['he', 'was', 'especially', 'fascinated', 'by', 'science', 'and', 'technology']
# ['he', 'wanted', 'to', 'understand', 'how', 'machines', 'think', 'and', 'whether', 'they', 'could', 'become', 'as', 'intelligent', 'as', 'humans']
# ['one', 'day', 'while', 'browsing', 'through', 'an', 'old', 'computer', 'at', 'school', 'arjun', 'discovered', 'the', 'concept', 'of', 'artificial', 'intelligence']
# ...

# %%
folder_path = r"C:\src\pyprojects\Full-Stack-GenAI-Bootcamp-1.0\04-12-2026\data"
story=[]
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path,filename)
    with open(file_path,encoding='unicode_escape') as f:
        corpus=f.read()
        raw_sent=sent_tokenize(corpus)
        for sent in raw_sent:
            story.append(simple_preprocess(sent))

# %%
story
# Out:
# [['once',
#   'upon',
#   'time',
#   'there',
#   'was',
#   'young',
#   'boy',
#   'named',
#   'arjun',
#   'who',
#   'lived',
#   'in',
#   'small',
#   'town',
#   'surrounded',
#   'by',
#   'hills',
#   'and',
#   'rivers'],
#  ['he',
#   'was',
#   'very',
#   'curious',
#   'about',
#   'how',
#   'things',
#   'worked',
#   'and',
#   'always',
#   'asked',
#   'questions'],
#  ['his',
#   'parents',
#   'often',
#   'smiled',
#   'at',
#   'his',
#   'curiosity',
#   'and',
#   'encouraged',
#   'him',
#   'to',
#   'learn',
#   'more'],
#  ['every',
#   'day',
#   'after',
#   'school',
#   'arjun',
#   'would',
#   'sit',
#   'with',
#   'his',
#   'books',
#   'and',
#   'explore',
#   'different',
#   'topics'],
#  ['he',
#   'was',
#   'especially',
#   'fascinated',
#   'by',
#   'science',
#   'and',
#   'technology'],
#  ['he',
#   'wanted',
#   'to',
#   'understand',
#   'how',
#   'machines',
#   'think',
#   'and',
#   'whether',
#   'they',
#   'could',
# ...

# %%
story[0]
# Out:
# ['once',
#  'upon',
#  'time',
#  'there',
#  'was',
#  'young',
#  'boy',
#  'named',
#  'arjun',
#  'who',
#  'lived',
#  'in',
#  'small',
#  'town',
#  'surrounded',
#  'by',
#  'hills',
#  'and',
#  'rivers']

# %%
story[1]
# Out:
# ['he',
#  'was',
#  'very',
#  'curious',
#  'about',
#  'how',
#  'things',
#  'worked',
#  'and',
#  'always',
#  'asked',
#  'questions']

# %% [markdown]
# # Word2vec(...,sg=0) # CBOW #by default
# # Word2vec(...,sg=1) # skip-gram

# %%
custom_model =gensim.models.word2vec(
    window=10,
    min_count=5,
    vector_size=150
)
## these all the value are the hyperparameters
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 custom_model = gensim.models.word2vec(
#       2     window=10,
#       3     min_count=5,
#       4     vector_size=150
#       5 )
#       6 ## these all the value are the hyperparameters
#
# TypeError: 'module' object is not callable

# %%
custom_model.build_vocab(story)
