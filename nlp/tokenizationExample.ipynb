# %%
# %pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
corpus ="""Hello welcome, to my NLP tuotorial practice.
Please do follow me for this samples! you difinitely like this NLP example.

"""

# %%
print(corpus)
# Out:
# Hello welcome, to my NLP tuotorial practice.
# Please do follow me for this samples! you difinitely like this NLP example.

# %%
## Tokenization
## Sentences --> Paragraphs
from nltk.tokenize import sent_tokenize

# %%
documents = sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello welcome, to my NLP tuotorial practice.
# Please do follow me for this samples!
# you difinitely like this NLP example.
